# %% [markdown]
# # Data Wrangling in Pandas
# * <b> Data Sorting:</b> To rearrange values in ascending or descending order.
# * <b> Data Filtration:</b> To create a subset of available data.
# * <b> Data Reduction:</b> To eliminate or replace unwanted values.
# * <b> Data Access:</b> To read or write data files.
# * <b> Data Processing:</b> To perform aggregation, statistical, and similar operations on specific values.

# %% [markdown]
# ## Organising data

# %% [markdown]
# A <b> Data frame </b> is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns.
#
# <b> Features of DataFrame </b>
# * Potentially columns are of different types
# * Size – Mutable
# * Labeled axes (rows and columns)
# * Can Perform Arithmetic operations on rows and columns

# %% [markdown]
# int, float, str, lists, tuples, dictionary

# %% [markdown]
# ### Creating empty DataFrame

# %%
import pandas as pd

# %%
df=pd.DataFrame()

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Creating DataFrame from list

# %%
l1=[12,14,16,70]

# %%
l1
# Out:
# [12, 14, 16, 70]

# %%
l2=[3,5,6,7,"Ruqia"]
l2
# Out:
# [3, 5, 6, 7, 'Ruqia']

# %%
l=l1+l2
l
# Out:
# [12, 14, 16, 70, 3, 5, 6, 7, 'Ruqia']

# %%
print(l)
# Out:
# [12, 14, 16, 70, 3, 5, 6, 7, 'Ruqia']

# %%
df1=pd.DataFrame(l)

# %%
print(df1)
# Out:
#        0
# 0     12
# 1     14
# 2     16
# 3     70
# 4      3
# 5      5
# 6      6
# 7      7
# 8  Ruqia

# %%
df = pd.DataFrame(
    { "Grades_M" : [1.8, 2, 3],
      "Grades_P" : [3, 14, 5],
      "Grades_c" : [5, 16, 7]},
      index = ["Jueria","Mazhar","Ulsoor"])

# %%
df
# Out:
#         Grades_M  Grades_P  Grades_c
# Jueria       1.8         3         5
# Mazhar       2.0        14        16
# Ulsoor       3.0         5         7

# %%
df2 = pd.DataFrame(
    [[1, 2, 3],
     [3, 4, 5],
     [5, 6, 7]],
      index = ["row1","row2","row3"],
      columns = ["a","b","c"])

# %%
df2
# Out:
#       a  b  c
# row1  1  2  3
# row2  3  4  5
# row3  5  6  7

# %%
data=[["Zainab",19],["Abu",21],["Arpita",20]]
myData=pd.DataFrame(data,columns=["Name","Age"])
print(myData)
# Out:
#      Name  Age
# 0  Zainab   19
# 1     Abu   21
# 2  Arpita   20

# %%
data=pd.read_csv('m3.csv')

# %%
data
# Out:
#                RA        deg  parallax  pm ra mas/yr  mas/yr  km/s
# 0      205.554938  28.057418    1.9800        -0.994  -2.891   NaN
# 1      205.543984  28.050690    0.2748        -1.053  -2.331   NaN
# 2      205.447593  28.057997   -0.6022         1.900  -3.358   NaN
# 3      205.440905  28.059873   -0.7141         2.345  -3.030   NaN
# 4      205.497631  28.066187   -0.1098         0.684  -2.854   NaN
# ...           ...        ...       ...           ...     ...   ...
# 36419  205.239603  28.563686   -0.8078        -1.864  -5.739   NaN
# 36420  205.258396  28.587312    1.0796        -0.926   4.779   NaN
# 36421  205.252042  28.584967   -0.0381       -11.468  15.493   NaN
# 36422  205.259945  28.584781    1.1579        -2.335  -1.705   NaN
# 36423  205.264758  28.598150    2.2108       -14.215 -33.066   NaN
#
# [36424 rows x 6 columns]

# %%
data.head(3)
# Out:
#            RA        deg  parallax  pm ra mas/yr  mas/yr  km/s
# 0  205.554938  28.057418    1.9800        -0.994  -2.891   NaN
# 1  205.543984  28.050690    0.2748        -1.053  -2.331   NaN
# 2  205.447593  28.057997   -0.6022         1.900  -3.358   NaN

# %%
data.tail(6)
# Out:
#                RA        deg  parallax  pm ra mas/yr  mas/yr  km/s
# 36418  205.230183  28.558208    0.2854        -2.869  -1.385   NaN
# 36419  205.239603  28.563686   -0.8078        -1.864  -5.739   NaN
# 36420  205.258396  28.587312    1.0796        -0.926   4.779   NaN
# 36421  205.252042  28.584967   -0.0381       -11.468  15.493   NaN
# 36422  205.259945  28.584781    1.1579        -2.335  -1.705   NaN
# 36423  205.264758  28.598150    2.2108       -14.215 -33.066   NaN

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
data.describe()
# Out:
#                  RA           deg      parallax  pm ra mas/yr        mas/yr  \
# count  36424.000000  36424.000000  25942.000000  25942.000000  25942.000000
# mean     205.549125     28.377614      0.085055     -0.320560     -2.776535
# std        0.086323      0.074493      1.511567      4.725651      3.359902
# min      205.172522     28.049914    -27.601800   -288.998000   -144.553000
# 25%      205.505572     28.341314     -0.368775     -0.956750     -3.254000
# 50%      205.548689     28.377114      0.053950     -0.078000     -2.635000
# 75%      205.592066     28.413631      0.518625      0.828750     -2.057000
# max      205.922821     28.706284     39.111800     49.467000     77.285000
#
#              km/s
# count   50.000000
# mean  -110.573800
# std     59.072323
# min   -155.800000
# 25%   -148.787500
# 50%   -144.445000
# 75%    -40.025000
# max      1.540000

# %%
type(data['deg'])
# Out:
# pandas.core.series.Series

# %%
type(data['parallax'])
# Out:
# pandas.core.series.Series

# %%
data.tail(20)
# Out:
#                RA        deg  parallax  pm ra mas/yr  mas/yr  km/s
# 36404  205.656458  28.666948   -1.8609         0.834  -2.901   NaN
# 36405  205.648477  28.666408    0.4564         0.608  -3.068   NaN
# 36406  205.634230  28.673956    2.0563        13.106 -13.173   NaN
# 36407  205.643607  28.689163    0.7742        -0.251  -4.196   NaN
# 36408  205.647337  28.665658    0.4069         2.811  -3.057   NaN
# 36409  205.646116  28.669716    2.6822        -3.944 -15.351   NaN
# 36410  205.642621  28.691394       NaN           NaN     NaN   NaN
# 36411  205.639528  28.674896    1.3893         1.952  -8.769   NaN
# 36412  205.675190  28.685900    0.5283        -1.066  -0.476   NaN
# 36413  205.604520  28.688732   -0.3729        -1.168  -2.108   NaN
# 36414  205.609069  28.687652    0.6389        -0.406  -1.592   NaN
# 36415  205.628356  28.701299    0.0283        -0.356  -3.493   NaN
# 36416  205.591823  28.706284    0.4089         1.984  -4.196   NaN
# ...

# %%
datasorted_Par=data.sort_values("parallax")
datasorted_Par.head()
# Out:
#                RA        deg  parallax  pm ra mas/yr  mas/yr  km/s
# 11575  205.523550  28.352232  -27.6018         3.255   9.485   NaN
# 12380  205.519165  28.359385  -22.2422       -13.798  25.595   NaN
# 29313  205.559801  28.401690  -19.9824        17.791   2.496   NaN
# 16098  205.547698  28.400862  -18.9046         1.724   2.732   NaN
# 6317   205.572945  28.366641  -16.2361         1.177   2.483   NaN

# %%
data.head(8)
# Out:
#            RA        deg  parallax  pm ra mas/yr  mas/yr  km/s
# 0  205.554938  28.057418    1.9800        -0.994  -2.891   NaN
# 1  205.543984  28.050690    0.2748        -1.053  -2.331   NaN
# 2  205.447593  28.057997   -0.6022         1.900  -3.358   NaN
# 3  205.440905  28.059873   -0.7141         2.345  -3.030   NaN
# 4  205.497631  28.066187   -0.1098         0.684  -2.854   NaN
# 5  205.475119  28.061051    3.5932       -35.483   9.421   NaN
# 6  205.505999  28.061270    3.8671       -13.848   3.652   NaN
# 7  205.501780  28.069863    2.0494       -21.883  13.337   NaN

# %%
data.tail()
# Out:
#                RA        deg  parallax  pm ra mas/yr  mas/yr  km/s
# 36419  205.239603  28.563686   -0.8078        -1.864  -5.739   NaN
# 36420  205.258396  28.587312    1.0796        -0.926   4.779   NaN
# 36421  205.252042  28.584967   -0.0381       -11.468  15.493   NaN
# 36422  205.259945  28.584781    1.1579        -2.335  -1.705   NaN
# 36423  205.264758  28.598150    2.2108       -14.215 -33.066   NaN

# %%
data_dropped_kms=data.drop(columns=["km/s"])
data_dropped_kms
# Out:
#                RA        deg  parallax  pm ra mas/yr  mas/yr
# 0      205.554938  28.057418    1.9800        -0.994  -2.891
# 1      205.543984  28.050690    0.2748        -1.053  -2.331
# 2      205.447593  28.057997   -0.6022         1.900  -3.358
# 3      205.440905  28.059873   -0.7141         2.345  -3.030
# 4      205.497631  28.066187   -0.1098         0.684  -2.854
# ...           ...        ...       ...           ...     ...
# 36419  205.239603  28.563686   -0.8078        -1.864  -5.739
# 36420  205.258396  28.587312    1.0796        -0.926   4.779
# 36421  205.252042  28.584967   -0.0381       -11.468  15.493
# 36422  205.259945  28.584781    1.1579        -2.335  -1.705
# 36423  205.264758  28.598150    2.2108       -14.215 -33.066
#
# [36424 rows x 5 columns]

# %%
data.head()
# Out:
#            RA        deg  parallax  pm ra mas/yr  mas/yr  km/s
# 0  205.554938  28.057418    1.9800        -0.994  -2.891   NaN
# 1  205.543984  28.050690    0.2748        -1.053  -2.331   NaN
# 2  205.447593  28.057997   -0.6022         1.900  -3.358   NaN
# 3  205.440905  28.059873   -0.7141         2.345  -3.030   NaN
# 4  205.497631  28.066187   -0.1098         0.684  -2.854   NaN

# %%
data.tail(10)
# Out:
#                RA        deg  parallax  pm ra mas/yr  mas/yr  km/s
# 36414  205.609069  28.687652    0.6389        -0.406  -1.592   NaN
# 36415  205.628356  28.701299    0.0283        -0.356  -3.493   NaN
# 36416  205.591823  28.706284    0.4089         1.984  -4.196   NaN
# 36417  205.244527  28.566771   -0.0888         0.792  -1.923   NaN
# 36418  205.230183  28.558208    0.2854        -2.869  -1.385   NaN
# 36419  205.239603  28.563686   -0.8078        -1.864  -5.739   NaN
# 36420  205.258396  28.587312    1.0796        -0.926   4.779   NaN
# 36421  205.252042  28.584967   -0.0381       -11.468  15.493   NaN
# 36422  205.259945  28.584781    1.1579        -2.335  -1.705   NaN
# 36423  205.264758  28.598150    2.2108       -14.215 -33.066   NaN

# %%
data.head(4)
# Out:
#            RA        deg  parallax  pm ra mas/yr  mas/yr  km/s
# 0  205.554938  28.057418    1.9800        -0.994  -2.891   NaN
# 1  205.543984  28.050690    0.2748        -1.053  -2.331   NaN
# 2  205.447593  28.057997   -0.6022         1.900  -3.358   NaN
# 3  205.440905  28.059873   -0.7141         2.345  -3.030   NaN

# %%
data.describe()
# Out:
#                  RA           deg      parallax  pm ra mas/yr        mas/yr  \
# count  36424.000000  36424.000000  25942.000000  25942.000000  25942.000000
# mean     205.549125     28.377614      0.085055     -0.320560     -2.776535
# std        0.086323      0.074493      1.511567      4.725651      3.359902
# min      205.172522     28.049914    -27.601800   -288.998000   -144.553000
# 25%      205.505572     28.341314     -0.368775     -0.956750     -3.254000
# 50%      205.548689     28.377114      0.053950     -0.078000     -2.635000
# 75%      205.592066     28.413631      0.518625      0.828750     -2.057000
# max      205.922821     28.706284     39.111800     49.467000     77.285000
#
#              km/s
# count   50.000000
# mean  -110.573800
# std     59.072323
# min   -155.800000
# 25%   -148.787500
# 50%   -144.445000
# 75%    -40.025000
# max      1.540000

# %%
myData.describe()
# Out:
#         Age
# count   3.0
# mean   20.0
# std     1.0
# min    19.0
# 25%    19.5
# 50%    20.0
# 75%    20.5
# max    21.0

# %%
df.describe()
# Out:
#        Grades_M   Grades_P   Grades_c
# count  3.000000   3.000000   3.000000
# mean   2.266667   7.333333   9.333333
# std    0.642910   5.859465   5.859465
# min    1.800000   3.000000   5.000000
# 25%    1.900000   4.000000   6.000000
# 50%    2.000000   5.000000   7.000000
# 75%    2.500000   9.500000  11.500000
# max    3.000000  14.000000  16.000000

# %%
data.columns=['RA','Dec','Parallax','PMRA','PMDEC','vrad']

# %%
print(data)
# Out:
#                RA        Dec  Parallax    PMRA   PMDEC  vrad
# 0      205.554938  28.057418    1.9800  -0.994  -2.891   NaN
# 1      205.543984  28.050690    0.2748  -1.053  -2.331   NaN
# 2      205.447593  28.057997   -0.6022   1.900  -3.358   NaN
# 3      205.440905  28.059873   -0.7141   2.345  -3.030   NaN
# 4      205.497631  28.066187   -0.1098   0.684  -2.854   NaN
# ...           ...        ...       ...     ...     ...   ...
# 36419  205.239603  28.563686   -0.8078  -1.864  -5.739   NaN
# 36420  205.258396  28.587312    1.0796  -0.926   4.779   NaN
# 36421  205.252042  28.584967   -0.0381 -11.468  15.493   NaN
# 36422  205.259945  28.584781    1.1579  -2.335  -1.705   NaN
# 36423  205.264758  28.598150    2.2108 -14.215 -33.066   NaN
#
# [36424 rows x 6 columns]

# %%
data
# Out:
#                RA        Dec  Parallax    PMRA   PMDEC  vrad
# 0      205.554938  28.057418    1.9800  -0.994  -2.891   NaN
# 1      205.543984  28.050690    0.2748  -1.053  -2.331   NaN
# 2      205.447593  28.057997   -0.6022   1.900  -3.358   NaN
# 3      205.440905  28.059873   -0.7141   2.345  -3.030   NaN
# 4      205.497631  28.066187   -0.1098   0.684  -2.854   NaN
# ...           ...        ...       ...     ...     ...   ...
# 36419  205.239603  28.563686   -0.8078  -1.864  -5.739   NaN
# 36420  205.258396  28.587312    1.0796  -0.926   4.779   NaN
# 36421  205.252042  28.584967   -0.0381 -11.468  15.493   NaN
# 36422  205.259945  28.584781    1.1579  -2.335  -1.705   NaN
# 36423  205.264758  28.598150    2.2108 -14.215 -33.066   NaN
#
# [36424 rows x 6 columns]

# %%
list_of_columns=['RA','Dec','Parallax']
data[list_of_columns]
#To look at columns
# Out:
#                RA        Dec  Parallax
# 0      205.554938  28.057418    1.9800
# 1      205.543984  28.050690    0.2748
# 2      205.447593  28.057997   -0.6022
# 3      205.440905  28.059873   -0.7141
# 4      205.497631  28.066187   -0.1098
# ...           ...        ...       ...
# 36419  205.239603  28.563686   -0.8078
# 36420  205.258396  28.587312    1.0796
# 36421  205.252042  28.584967   -0.0381
# 36422  205.259945  28.584781    1.1579
# 36423  205.264758  28.598150    2.2108
#
# [36424 rows x 3 columns]

# %%
data.loc[[6,7,14]]
#To look at rows, use the loc
# Out:
#             RA        Dec  Parallax    PMRA   PMDEC  vrad
# 6   205.505999  28.061270    3.8671 -13.848   3.652   NaN
# 7   205.501780  28.069863    2.0494 -21.883  13.337   NaN
# 14  205.462879  28.086811    1.2009  -4.205  -6.091   NaN

# %%
data.loc[[100,101,102],['RA','Dec']]
# Out:
#              RA        Dec
# 100  205.745220  28.197679
# 101  205.765714  28.191480
# 102  205.765956  28.187889

# %%
data['RA+Dec']=data['RA']+data['Dec']

# %%
data['2RA']=data['RA']*2
data['RA+2']=data['RA']+2
#Basic Intuitive algebra is applicable to dataframes (or more specifically, series)

# %%
def square_plus_one(number):
    return number*number+1

# %%
square_plus_one(2)
# Out:
# 5

# %%
data['RA_Square_plus_one']=data['RA'].apply(square_plus_one)

# %%
data['RA_Square_plus_one']
# Out:
# 0        42253.832527
# 1        42249.329431
# 2        42209.713405
# 3        42206.965608
# 4        42230.276438
#              ...
# 36419    42124.294790
# 36420    42132.008965
# 36421    42129.400638
# 36422    42132.644956
# 36423    42134.620945
# Name: RA_Square_plus_one, Length: 36424, dtype: float64

# %%
#!pip install ydata_profiling

# %%
from ydata_profiling import ProfileReport
report = ProfileReport(data)
report

# %%
report.to_file("data_report.html")

# %%
#!pip install ipywidgets
# Out:
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\DELL\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\DELL\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\DELL\anaconda3\Lib\site-packages)

# %%
#!conda install -c conda-forge ipympl

# %%
report.to_widgets()
